# %% [markdown]
# ##### Reading OBE Marksheet

# %%
import pandas as pd
file = pd.read_excel('CSE104 OBE Mark Sheet.xlsx')

# %%
file.head(10)
# Out:
#    Serial         ID Course ID  Section  Semester Midterm Unnamed: 6  \
# 0     NaN        NaN       NaN       NaN      NaN     CO1        CO1
# 1     NaN        NaN       NaN       NaN      NaN      Q1         Q2
# 2     NaN        NaN       NaN       NaN      NaN      25         25
# 3     1.0  1416455.0    CSE104       1.0   Summer      15          0
# 4     2.0  1579288.0    CSE104       1.0   Summer       0          0
# 5     3.0  1528882.0    CSE104       3.0   Summer      15          7
# 6     4.0  1653725.0    CSE104       3.0   Summer       0          0
# 7     5.0  1625654.0    CSE104       1.0   Summer       5         15
# 8     6.0  1669953.0    CSE104       3.0   Summer       0          0
# 9     7.0  1665555.0    CSE104       1.0   Summer      10          0
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Final Total  Final Total Converted  \
# 0        CO1        CO2        CO1  ...       100.0                   40.0
# ...

# %% [markdown]
# ##### Slicing data for student enrollment table

# %%
enrollment = file.iloc[3:, :5]   # taking upto semester column 
enrollment.head()
# Out:
#    Serial         ID Course ID  Section  Semester
# 3     1.0  1416455.0    CSE104       1.0   Summer
# 4     2.0  1579288.0    CSE104       1.0   Summer
# 5     3.0  1528882.0    CSE104       3.0   Summer
# 6     4.0  1653725.0    CSE104       3.0   Summer
# 7     5.0  1625654.0    CSE104       1.0   Summer

# %%
enrollment = enrollment.drop(enrollment.columns[[2]], axis= 1) # dropping course ID column # As we need 4 columns
enrollment.head()
# Out:
#    Serial         ID  Section  Semester
# 3     1.0  1416455.0       1.0   Summer
# 4     2.0  1579288.0       1.0   Summer
# 5     3.0  1528882.0       3.0   Summer
# 6     4.0  1653725.0       3.0   Summer
# 7     5.0  1625654.0       1.0   Summer

# %%
# Converting dataframe to list
enrollment_l = enrollment.values.tolist()

# %%
for i in range(len(enrollment_l)):
    enrollment_l[i][0] = 2000 + i            # primary key
    enrollment_l[i][1] = int(enrollment_l[i][1])
    enrollment_l[i][2] = 'cse104_' + str(int(enrollment_l[i][2]))
    
print(enrollment_l[13])
# Out:
# [2013, 1674181, 'cse104_3', 'Summer']

# %%
# Converting list dataframe
df = pd.DataFrame(enrollment_l,columns=['Student Enrollment ID', 'Student ID', 'Section ID', 'Semester'] )
df.head()
# Out:
#    Student Enrollment ID  Student ID Section ID Semester
# 0                   2000     1416455   cse104_1   Summer
# 1                   2001     1579288   cse104_1   Summer
# 2                   2002     1528882   cse104_3   Summer
# 3                   2003     1653725   cse104_3   Summer
# 4                   2004     1625654   cse104_1   Summer

# %%
df.tail()
# Out:
#     Student Enrollment ID  Student ID Section ID Semester
# 83                   2083     1868128   cse104_1   Summer
# 84                   2084     1845457   cse104_1   Summer
# 85                   2085     1855787   cse104_2   Summer
# 86                   2086     1893863   cse104_2   Summer
# 87                   2087     1842333   cse104_2   Summer

# %%
df.to_excel('student_enrollment_cse104.xlsx')
